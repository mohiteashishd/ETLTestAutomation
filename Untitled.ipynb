# %%
import pandas as pd

# %%
df = pd.read_csv('NSE.csv')

# %%
type(df[['SYMBOL','OPEN','HIGH','LOW','CHNG']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   SYMBOL                      51 non-null     object
#  1   OPEN                        51 non-null     object
#  2   HIGH                        51 non-null     object
#  3   LOW                         51 non-null     object
#  4   PREV. CLOSE                 51 non-null     object
#  5   LTP                         51 non-null     object
#  6   CHNG                        51 non-null     float64
#  7   %CHNG                       51 non-null     float64
#  8   VOLUME (shares)             51 non-null     object
#  9   VALUE (₹ Crores)            51 non-null     object
#  10  52W H                       51 non-null     object
#  11  52W L                       51 non-null     object
#  12  30 D   %CHNG                51 non-null     float64
#  13  365 D % CHNG
# ...

# %%
df.head(10)
# Out:
#        SYMBOL       OPEN       HIGH        LOW PREV. CLOSE        LTP    CHNG  \
# 0    NIFTY 50  24,999.40  25,130.50  24,896.80   24,936.40  25,041.10  104.70
# 1    DIVISLAB   5,200.95   5,447.35   5,198.00    5,173.50   5,444.00  270.50
# 2        LTIM   6,205.65   6,400.00   6,177.30    6,146.60   6,332.00  185.40
# 3        NTPC      390.1      399.4     389.75      389.85     399.15    9.30
# 4  BHARTIARTL   1,545.15   1,586.00   1,545.15    1,542.65   1,577.10   34.45
# 5       WIPRO      516.8        528        514      514.85     525.25   10.40
# 6     HCLTECH   1,749.45   1,789.30   1,747.15    1,746.75   1,781.60   34.85
# 7       TECHM   1,592.00   1,613.70   1,578.50    1,579.20   1,610.65   31.45
# 8   POWERGRID        327      335.3        327      328.55     334.75    6.20
# 9  BAJAJ-AUTO  10,793.40  11,035.70  10,780.05   10,847.60  11,024.95  177.35
#
#    %CHNG VOLUME (shares) VALUE (₹ Crores)     52W H      52W L   \
# ...

# %%
df
