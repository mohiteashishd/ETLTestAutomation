# %%
import pymssql
import pyodbc
from sqlalchemy import create_engine 
import pandas as pd
conn = pyodbc.connect('DRIVER={SQL Server};SERVER=LAPTOP-TGGKGTLU;DATABASE=HR;UID=mohiteashishd;PWD=123456')

# %%
query = 'select * from employees'

# %%
df_target = pd.read_sql(query, conn)
# Out:
# C:\Users\AshishMohite\AppData\Local\Temp\ipykernel_15160\3283388754.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_target = pd.read_sql(query, conn)

# %%
df_target
# Out:
#     employee_id   first_name    last_name                          email  \
# 0           100       Steven         King        steven.king@hotmail.com
# 1           101        Neena      Kochhar      neena.kochhar@hotmail.com
# 2           102          Lex      De Haan        lex.de haan@hotmail.com
# 3           103    Alexander       Hunold     alexander.hunold@yahoo.com
# 4           104        Bruce        Ernst          bruce.ernst@yahoo.com
# 5           105        David       Austin         david.austin@yahoo.com
# 6           106        Valli    Pataballa      valli.pataballa@yahoo.com
# 7           107        Diana      Lorentz        diana.lorentz@yahoo.com
# 8           108        Nancy    Greenberg      nancy.greenberg@gmail.com
# 9           109       Daniel       Faviet        daniel.faviet@gmail.com
# 10          110         John         Chen            john.chen@gmail.com
# 11          111       Ismael      Sciarra       ismael.sciarra@gmail.com
# ...

# %%
df_source = pd.read_csv('EMP.csv')

# %%
df_source
# Out:
#     employee_id   first_name    last_name                           email  \
# 0           100       Steven         King         steven.king@hotmail.com
# 1           101        Neena      Kochhar       neena.kochhar@hotmail.com
# 2           102          Lex      De Haan         lex.de haan@hotmail.com
# 3           103    Alexander       Hunold      alexander.hunold@yahoo.com
# 4           104        Bruce        Ernst           bruce.ernst@yahoo.com
# 5           105        David       Austin          david.austin@yahoo.com
# 6           106        Valli    Pataballa       valli.pataballa@yahoo.com
# 7           107        Diana      Lorentz         diana.lorentz@yahoo.com
# 8           108        Nancy    Greenberg       nancy.greenberg@gmail.com
# 9           109       Daniel       Faviet         daniel.faviet@gmail.com
# 10          110         John         Chen             john.chen@gmail.com
# 11          111       Ismael      Sciarra        ismael.sciarra@gmail.com
# ...

# %%
~df_source['employee_id'].isin(df_target['employee_id'])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# Name: employee_id, dtype: bool

# %%
df_SrcVSTrgt = df_source[~df_source['employee_id'].isin(df_target['employee_id'])]

# %%
df_SrcVSTrgt
# Out:
#     employee_id first_name  last_name                           email  \
# 40          207    Michael  Hartstein  michael.hartstein1@hotmail.com
# 41          208        Pat        Fay            pat.fay1@hotmail.com
# 42          209      Susan     Mavris       susan.mavris1@hotmail.com
# 43          210    Hermann       Baer       hermann.baer1@hotmail.com
# 44          211    Shelley    Higgins    shelley.higgins1@hotmail.com
# 45          212    William      Gietz      william.gietz1@hotmail.com
#
#     phone_number  hire_date  job_id  salary  manager_id  department_id  year
# 40  5.151236e+09  2-17-1996      10   13001       100.0              2  1996
# 41  6.031237e+09  8-17-1997      11    6001       201.0              2  1997
# 42  5.151238e+09   06-07-94       8    6501       101.0              4  1994
# 43  5.151239e+09   06-07-94      12   10001       101.0              7  1994
# 44  5.151238e+09   06-07-94       2   12001       101.0             11  1994
# ...
